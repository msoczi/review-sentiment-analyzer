# %% [markdown]
# # 3. Training BILSTM
#
# BILSTM network training took place over many sessions due to the long computation time. We trained only 12 epoch.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import pickle

import tensorflow as tf
import keras
from keras.models import Sequential
from keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
# Read the data
X_train = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/X_train.npy')
X_test = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/X_test.npy')
y_train = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/y_train.npy')
y_test = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/y_test.npy')

# %%
# read pretrained BILSTM model 
model_BILSTM = tf.keras.models.load_model('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_1')

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=2,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/2
# 11599/11599 [==============================] - 2334s 201ms/step - loss: 0.5838 - accuracy: 0.7554 - val_loss: 0.5679 - val_accuracy: 0.7626
# Epoch 2/2
# 11599/11599 [==============================] - 2316s 200ms/step - loss: 0.5705 - accuracy: 0.7621 - val_loss: 0.5498 - val_accuracy: 0.7704

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_3')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_3/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f97104e7d10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=2,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/2
# 11599/11599 [==============================] - 2306s 199ms/step - loss: 0.5652 - accuracy: 0.7643 - val_loss: 0.5536 - val_accuracy: 0.7699
# Epoch 2/2
# 11599/11599 [==============================] - 2308s 199ms/step - loss: 0.5617 - accuracy: 0.7656 - val_loss: 0.5591 - val_accuracy: 0.7650

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_5')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_5/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_5/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f97104e7d10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=2,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/2
# 11599/11599 [==============================] - 2302s 198ms/step - loss: 0.5600 - accuracy: 0.7661 - val_loss: 0.5493 - val_accuracy: 0.7695
# Epoch 2/2
# 11599/11599 [==============================] - 2289s 197ms/step - loss: 0.5602 - accuracy: 0.7653 - val_loss: 0.5441 - val_accuracy: 0.7716

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_7')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_7/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_7/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5de028ba50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=2,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/2
# 11599/11599 [==============================] - 2279s 196ms/step - loss: 0.5594 - accuracy: 0.7660 - val_loss: 0.5471 - val_accuracy: 0.7716
# Epoch 2/2
# 11599/11599 [==============================] - 2272s 196ms/step - loss: 0.5592 - accuracy: 0.7663 - val_loss: 0.5443 - val_accuracy: 0.7722

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_9')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_9/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/model_epoch_9/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5de028ba50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=1,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# 11599/11599 [==============================] - 2324s 200ms/step - loss: 0.5594 - accuracy: 0.7670 - val_loss: 0.5505 - val_accuracy: 0.7676

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_10')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_10/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_10/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f61b0086c90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...

# %%
# Train 
history = model_BILSTM.fit(X_train, 
                     y_train, 
                     epochs=2,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/2
# 11599/11599 [==============================] - 2287s 196ms/step - loss: 0.5578 - accuracy: 0.7672 - val_loss: 0.5444 - val_accuracy: 0.7720
# Epoch 2/2
# 11599/11599 [==============================] - 2249s 194ms/step - loss: 0.5572 - accuracy: 0.7675 - val_loss: 0.5428 - val_accuracy: 0.7726

# %%
# Save the model
model_BILSTM.save('/content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_12')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_12/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/BILSTM/model_epoch_12/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f4d70079ad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ...
