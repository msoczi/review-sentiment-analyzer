# %% [markdown]
# # 4. Training CNN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import pickle

import tensorflow as tf
import keras
from keras.models import Sequential
from keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam
from keras import regularizers

# %%
# Read the data
X_train = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/X_train.npy')
X_test = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/X_test.npy')
y_train = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/y_train.npy')
y_test = np.load('/content/drive/MyDrive/INL_PROJEKT/preprocessed_data/y_test.npy')

# %%
# load CONV model
model_CONV = tf.keras.models.load_model('/content/drive/MyDrive/INL_PROJEKT/CONV/model_epoch_1')

# %%
# Train 
history = model_CONV.fit(X_train, 
                     y_train, 
                     epochs=4,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/4
# 11599/11599 [==============================] - 144s 11ms/step - loss: 0.6618 - acc: 0.7323 - val_loss: 0.6531 - val_acc: 0.7334
# Epoch 2/4
# 11599/11599 [==============================] - 135s 12ms/step - loss: 0.6384 - acc: 0.7425 - val_loss: 0.6626 - val_acc: 0.7278
# Epoch 3/4
# 11599/11599 [==============================] - 135s 12ms/step - loss: 0.6260 - acc: 0.7479 - val_loss: 0.6336 - val_acc: 0.7402
# Epoch 4/4
# 11599/11599 [==============================] - 135s 12ms/step - loss: 0.6178 - acc: 0.7519 - val_loss: 0.6322 - val_acc: 0.7416

# %%
# Save the model
model_CONV.save('/content/drive/MyDrive/INL_PROJEKT/CONV/model_epoch_5')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/CONV/model_epoch_5/assets

# %%
# Train 
history = model_CONV.fit(X_train, 
                     y_train, 
                     epochs=5,
                     validation_data=(X_test, y_test),
                     verbose = 1)
# Out:
# Epoch 1/5
# 11599/11599 [==============================] - 132s 11ms/step - loss: 0.6116 - acc: 0.7549 - val_loss: 0.6311 - val_acc: 0.7418
# Epoch 2/5
# 11599/11599 [==============================] - 127s 11ms/step - loss: 0.6065 - acc: 0.7575 - val_loss: 0.6339 - val_acc: 0.7413
# Epoch 3/5
# 11599/11599 [==============================] - 135s 12ms/step - loss: 0.6024 - acc: 0.7594 - val_loss: 0.6531 - val_acc: 0.7309
# Epoch 4/5
# 11599/11599 [==============================] - 133s 12ms/step - loss: 0.5984 - acc: 0.7614 - val_loss: 0.6495 - val_acc: 0.7328
# Epoch 5/5
# 11599/11599 [==============================] - 135s 12ms/step - loss: 0.5951 - acc: 0.7634 - val_loss: 0.6529 - val_acc: 0.7335

# %%
# Save the model
model_CONV.save('/content/drive/MyDrive/INL_PROJEKT/CONV/model_epoch_10')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/INL_PROJEKT/CONV/model_epoch_10/assets
